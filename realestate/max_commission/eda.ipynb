# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('hist.csv')
#df = df.loc[df['commission']!=0]
sorteddf = df.groupby(by=['rooms','floors','baths','lotSize','price']).sum().reset_index()
filtered_df = sorteddf.loc[(sorteddf['rooms'] == 1) & (sorteddf['floors'] == 2) & (sorteddf['baths'] == 2) ]
print(filtered_df.head())
# Out:
# Empty DataFrame
# Columns: [rooms, floors, baths, lotSize, price, saleResult, commission]
# Index: []

# %%
filtered_df = sorteddf.loc[(sorteddf['saleResult']== 'Sold')]
#filtered_df = sorteddf.loc[(sorteddf['rooms'] == 1) & (sorteddf['floors'] == 1) & (sorteddf['baths'] == 1) ]
sns.relplot(data=sorteddf, x='lotSize', y='price', kind='scatter', height=6, aspect=1.5,hue='saleResult',alpha=0.025,col='floors')
plt.show()
print(filtered_df)
# Out:
#         rooms  floors  baths  lotSize     price saleResult  commission
# 1         1.0     1.0    1.0   1001.0  253830.0       Sold    15229.80
# 2         1.0     1.0    1.0   1002.0  243004.0       Sold    14580.24
# 3         1.0     1.0    1.0   1005.0  263882.0       Sold    15832.92
# 4         1.0     1.0    1.0   1005.0  280878.0       Sold    16852.68
# 5         1.0     1.0    1.0   1007.0  227735.0       Sold    13664.10
# ...       ...     ...    ...      ...       ...        ...         ...
# 115378    6.0     3.0    3.0   4998.0  244033.0       Sold    14641.98
# 115380    6.0     3.0    3.0   4999.0  241489.0       Sold    14489.34
# 115381    6.0     3.0    3.0   5000.0  222320.0       Sold    13339.20
# 115382    6.0     3.0    3.0   5000.0  232171.0       Sold    13930.26
# 115383    6.0     3.0    3.0   5000.0  236849.0       Sold    14210.94
#
# [78207 rows x 7 columns]

# %%
sns.relplot(data=sorteddf,x='lotSize',y='price',hue='floors')
